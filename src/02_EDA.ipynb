# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO
import os
import json
from collections import OrderedDict

# %%
## Readin Files
#path = '/work/'
path = './data/pickle/'

explanation_of_benefit_df = pd.read_pickle(path + 'explanation_of_benefit.pkl')
coverage_df = pd.read_pickle(path + 'coverage.pkl')
patient_df = pd.read_pickle(path + 'patient.pkl')
#claim_df = pd.read_pickle(path + 'claim.pkl')
claim_response_df = pd.read_pickle(path + 'claim_response.pkl')

# %%
print("Explanation of Benefit Columns:")
print(explanation_of_benefit_df.columns)
print("\nCoverage Columns:")
print(coverage_df.columns)
print("\nPatient Columns:")
print(patient_df.columns)
# print("\nClaim Columns:")
# print(claim_df.columns)
print("\nClaim Response Columns:")
print(claim_response_df.columns)
# Out:
# Explanation of Benefit Columns:
# Index(['benefitBalance_0_category_coding_0_code',
#        'benefitBalance_0_category_coding_0_display',
#        'benefitBalance_0_category_coding_0_system',
#        'benefitBalance_0_financial_0_type_coding_0_code',
#        'benefitBalance_0_financial_0_type_coding_0_display',
#        'benefitBalance_0_financial_0_type_coding_0_system',
#        'benefitBalance_0_financial_0_usedMoney_currency',
#        'benefitBalance_0_financial_0_usedMoney_value',
#        'benefitBalance_0_financial_1_type_coding_0_code',
#        'benefitBalance_0_financial_1_type_coding_0_display',
#        ...
#        'diagnosis_17_type_0_coding_0_display',
#        'diagnosis_17_type_0_coding_0_system', 'procedure_20_date',
#        'procedure_20_procedureCodeableConcept_coding_0_code',
#        'procedure_20_procedureCodeableConcept_coding_0_display',
#        'procedure_20_procedureCodeableConcept_coding_0_system',
#        'procedure_20_procedureCodeableConcept_coding_1_code',
#        'procedure_20_procedureCodeableConcept_coding_1_display',
#        'procedure_20_procedureCodeableConcept_coding_1_system',
#        'procedure_20_sequence'],
#       dtype='object', length=900)
#
# Coverage Columns:
# Index(['beneficiary_reference', 'class_0_type_coding_0_code',
#        'class_0_type_coding_0_display', 'class_0_type_coding_0_system',
#        'class_0_value', 'class_1_type_coding_0_code',
#        'class_1_type_coding_0_display', 'class_1_type_coding_0_system',
#        'class_1_value', 'extension_0_url',
#        ...
#        'extension_107_valueCoding_display',
#        'extension_108_valueCoding_display',
#        'extension_109_valueCoding_display',
#        'extension_110_valueCoding_display',
#        'extension_111_valueCoding_display',
#        'extension_112_valueCoding_display',
#        'extension_113_valueCoding_display',
#        'extension_114_valueCoding_display',
#        'extension_115_valueCoding_display',
#        'extension_116_valueCoding_display'],
#       dtype='object', length=638)
#
# Patient Columns:
# Index(['address_0_state', 'birthDate', 'deceasedBoolean', 'extension_0_url',
#        'extension_0_valueCode', 'extension_1_url',
#        'extension_1_valueCoding_code', 'extension_1_valueCoding_display',
#        'extension_1_valueCoding_system', 'extension_2_extension_0_url',
#        'extension_2_extension_0_valueCoding_code',
#        'extension_2_extension_0_valueCoding_display',
#        'extension_2_extension_0_valueCoding_system',
#        'extension_2_extension_1_url', 'extension_2_extension_1_valueString',
#        'extension_2_url', 'extension_3_url', 'extension_3_valueDate', 'gender',
#        'id', 'identifier_0_system', 'identifier_0_type_coding_0_code',
#        'identifier_0_type_coding_0_display',
#        'identifier_0_type_coding_0_system', 'identifier_0_value',
#        'identifier_1_system', 'identifier_1_type_coding_0_code',
#        'identifier_1_type_coding_0_display',
#        'identifier_1_type_coding_0_extension_0_url',
#        'identifier_1_type_coding_0_extension_0_valueCoding_code',
#        'identifier_1_type_coding_0_extension_0_valueCoding_display',
#        'identifier_1_type_coding_0_extension_0_valueCoding_system',
#        'identifier_1_type_coding_0_system', 'identifier_1_value',
#        'meta_lastUpdated', 'meta_profile', 'name_0_family', 'name_0_given',
#        'name_0_use', 'resourceType', 'address_0_postalCode',
#        'identifier_2_system', 'identifier_2_type_coding_0_code',
#        'identifier_2_type_coding_0_display',
#        'identifier_2_type_coding_0_extension_0_url',
#        'identifier_2_type_coding_0_extension_0_valueCoding_code',
#        'identifier_2_type_coding_0_extension_0_valueCoding_display',
#        'identifier_2_type_coding_0_extension_0_valueCoding_system',
#        'identifier_2_type_coding_0_system', 'identifier_2_value'],
#       dtype='object')
#
# Claim Response Columns:
# Index(['contained_0_birthDate', 'contained_0_extension_0_url',
#        'contained_0_extension_0_valueCode', 'contained_0_gender',
#        'contained_0_id', 'contained_0_identifier_0_system',
#        'contained_0_identifier_0_type_coding_0_code',
#        'contained_0_identifier_0_type_coding_0_display',
#        'contained_0_identifier_0_type_coding_0_system',
#        'contained_0_identifier_0_value', 'contained_0_name_0_family',
#        'contained_0_name_0_given', 'contained_0_name_0_text',
#        'contained_0_resourceType', 'created', 'extension_0_url',
#        'extension_0_valueCoding_code', 'extension_0_valueCoding_system',
#        'extension_1_url', 'extension_1_valueDate', 'extension_2_url',
#        'extension_2_valueDate', 'id', 'identifier_0_system',
#        'identifier_0_type_coding_0_code', 'identifier_0_type_coding_0_display',
#        'identifier_0_type_coding_0_system', 'identifier_0_value',
#        'insurer_identifier_value', 'meta_lastUpdated', 'outcome',
#        'patient_reference', 'request_reference', 'resourceType', 'status',
#        'type_coding_0_code', 'type_coding_0_display', 'type_coding_0_system',
#        'use'],
#       dtype='object')

# %%
eob_cols = explanation_of_benefit_df.columns.values.tolist()
df = pd.DataFrame(data={"col1": eob_cols})
df.to_csv('../doc/eob_columns.csv', header=True, index=False)

cov_cols = coverage_df.columns.values.tolist()
df = pd.DataFrame(data={"col1": cov_cols})
df.to_csv('../doc/coverage_columns.csv', header=True, index=False)

pat_cols = patient_df.columns.values.tolist()
df = pd.DataFrame(data={"col1": pat_cols})
df.to_csv('../doc/patient_columns.csv', header=True, index=False)

# claim_cols = claim_df.columns.values.tolist()
# df = pd.DataFrame(data={"col1": claim_cols})
# df.to_csv('../doc/claim_columns.csv', header=True, index=False)

claimres_cols = claim_response_df.columns.values.tolist()
df = pd.DataFrame(data={"col1": claimres_cols})
df.to_csv('../doc/claim_response_columns.csv', header=True, index=False)

# %%
explanation_of_benefit_df.head(50).tail(10)
# Out:
#    benefitBalance_0_category_coding_0_code  \
# 40                                       1
# 41                                       1
# 42                                       1
# 43                                       1
# 44                                       1
# 45                                       1
# 46                                       1
# 47                                       1
# 48                                       1
# 49                                       1
#
#    benefitBalance_0_category_coding_0_display  \
# 40                               Medical Care
# 41                               Medical Care
# 42                               Medical Care
# 43                               Medical Care
# 44                               Medical Care
# 45                               Medical Care
# 46                               Medical Care
# 47                               Medical Care
# 48                               Medical Care
# 49                               Medical Care
#
#             benefitBalance_0_category_coding_0_system  \
# 40  http://terminology.hl7.org/CodeSystem/ex-benef...
# 41  http://terminology.hl7.org/CodeSystem/ex-benef...
# 42  http://terminology.hl7.org/CodeSystem/ex-benef...
# 43  http://terminology.hl7.org/CodeSystem/ex-benef...
# 44  http://terminology.hl7.org/CodeSystem/ex-benef...
# 45  http://terminology.hl7.org/CodeSystem/ex-benef...
# 46  http://terminology.hl7.org/CodeSystem/ex-benef...
# 47  http://terminology.hl7.org/CodeSystem/ex-benef...
# 48  http://terminology.hl7.org/CodeSystem/ex-benef...
# 49  http://terminology.hl7.org/CodeSystem/ex-benef...
#
#       benefitBalance_0_financial_0_type_coding_0_code  \
# 40  https://bluebutton.cms.gov/resources/variables...
# 41  https://bluebutton.cms.gov/resources/variables...
# 42  https://bluebutton.cms.gov/resources/variables...
# 43  https://bluebutton.cms.gov/resources/variables...
# 44  https://bluebutton.cms.gov/resources/variables...
# 45  https://bluebutton.cms.gov/resources/variables...
# 46  https://bluebutton.cms.gov/resources/variables...
# 47  https://bluebutton.cms.gov/resources/variables...
# 48  https://bluebutton.cms.gov/resources/variables...
# 49  https://bluebutton.cms.gov/resources/variables...
#
#    benefitBalance_0_financial_0_type_coding_0_display  \
# 40               Professional Component Charge Amount
# 41               Professional Component Charge Amount
# 42               Professional Component Charge Amount
# 43               Professional Component Charge Amount
# 44               Professional Component Charge Amount
# 45               Professional Component Charge Amount
# 46               Professional Component Charge Amount
# 47               Professional Component Charge Amount
# 48               Professional Component Charge Amount
# 49               Professional Component Charge Amount
#
#     benefitBalance_0_financial_0_type_coding_0_system  \
# 40  https://bluebutton.cms.gov/resources/codesyste...
# 41  https://bluebutton.cms.gov/resources/codesyste...
# 42  https://bluebutton.cms.gov/resources/codesyste...
# 43  https://bluebutton.cms.gov/resources/codesyste...
# 44  https://bluebutton.cms.gov/resources/codesyste...
# 45  https://bluebutton.cms.gov/resources/codesyste...
# 46  https://bluebutton.cms.gov/resources/codesyste...
# 47  https://bluebutton.cms.gov/resources/codesyste...
# 48  https://bluebutton.cms.gov/resources/codesyste...
# 49  https://bluebutton.cms.gov/resources/codesyste...
#
#    benefitBalance_0_financial_0_usedMoney_currency  \
# 40                                             USD
# 41                                             USD
# 42                                             USD
# 43                                             USD
# 44                                             USD
# 45                                             USD
# 46                                             USD
# 47                                             USD
# 48                                             USD
# 49                                             USD
#
#     benefitBalance_0_financial_0_usedMoney_value  \
# 40                                           4.0
# 41                                           4.0
# 42                                           4.0
# 43                                           4.0
# 44                                           4.0
# 45                                           4.0
# 46                                           4.0
# 47                                           4.0
# 48                                           4.0
# 49                                           4.0
#
#       benefitBalance_0_financial_1_type_coding_0_code  \
# 40  https://bluebutton.cms.gov/resources/variables...
# 41  https://bluebutton.cms.gov/resources/variables...
# 42  https://bluebutton.cms.gov/resources/variables...
# 43  https://bluebutton.cms.gov/resources/variables...
# 44  https://bluebutton.cms.gov/resources/variables...
# 45  https://bluebutton.cms.gov/resources/variables...
# 46  https://bluebutton.cms.gov/resources/variables...
# 47  https://bluebutton.cms.gov/resources/variables...
# 48  https://bluebutton.cms.gov/resources/variables...
# 49  https://bluebutton.cms.gov/resources/variables...
#
#    benefitBalance_0_financial_1_type_coding_0_display  ...  \
# 40           NCH Beneficiary Part B Deductible Amount  ...
# 41           NCH Beneficiary Part B Deductible Amount  ...
# 42           NCH Beneficiary Part B Deductible Amount  ...
# 43           NCH Beneficiary Part B Deductible Amount  ...
# 44           NCH Beneficiary Part B Deductible Amount  ...
# 45           NCH Beneficiary Part B Deductible Amount  ...
# 46           NCH Beneficiary Part B Deductible Amount  ...
# 47           NCH Beneficiary Part B Deductible Amount  ...
# 48           NCH Beneficiary Part B Deductible Amount  ...
# 49           NCH Beneficiary Part B Deductible Amount  ...
#
#    diagnosis_17_type_0_coding_0_display diagnosis_17_type_0_coding_0_system  \
# 40                                  NaN                                 NaN
# 41                                  NaN                                 NaN
# 42                                  NaN                                 NaN
# 43                                  NaN                                 NaN
# 44                                  NaN                                 NaN
# 45                                  NaN                                 NaN
# 46                                  NaN                                 NaN
# 47                                  NaN                                 NaN
# 48                                  NaN                                 NaN
# 49                                  NaN                                 NaN
#
#     procedure_20_date procedure_20_procedureCodeableConcept_coding_0_code  \
# 40                NaN                                                NaN
# 41                NaN                                                NaN
# 42                NaN                                                NaN
# 43                NaN                                                NaN
# 44                NaN                                                NaN
# 45                NaN                                                NaN
# 46                NaN                                                NaN
# 47                NaN                                                NaN
# 48                NaN                                                NaN
# 49                NaN                                                NaN
#
#    procedure_20_procedureCodeableConcept_coding_0_display  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    procedure_20_procedureCodeableConcept_coding_0_system  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    procedure_20_procedureCodeableConcept_coding_1_code  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     procedure_20_procedureCodeableConcept_coding_1_display  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    procedure_20_procedureCodeableConcept_coding_1_system procedure_20_sequence
# 40                                                NaN                      NaN
# 41                                                NaN                      NaN
# 42                                                NaN                      NaN
# 43                                                NaN                      NaN
# 44                                                NaN                      NaN
# 45                                                NaN                      NaN
# 46                                                NaN                      NaN
# 47                                                NaN                      NaN
# 48                                                NaN                      NaN
# 49                                                NaN                      NaN
#
# [10 rows x 900 columns]

# %%
coverage_df.head(50).tail(10)
# Out:
#       beneficiary_reference class_0_type_coding_0_code  \
# 40  Patient/-10000000000022                      group
# 41  Patient/-10000000000022                      group
# 42  Patient/-10000000000022                      group
# 43  Patient/-10000000000022                      group
# 44  Patient/-10000000000082                      group
# 45  Patient/-10000000000082                      group
# 46  Patient/-10000000000082                      group
# 47  Patient/-10000000000082                      group
# 48  Patient/-10000000000070                      group
# 49  Patient/-10000000000070                      group
#
#    class_0_type_coding_0_display  \
# 40                         Group
# 41                         Group
# 42                         Group
# 43                         Group
# 44                         Group
# 45                         Group
# 46                         Group
# 47                         Group
# 48                         Group
# 49                         Group
#
#                          class_0_type_coding_0_system class_0_value  \
# 40  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 41  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 42  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 43  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 44  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 45  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 46  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 47  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 48  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# 49  http://terminology.hl7.org/CodeSystem/coverage...      Medicare
#
#    class_1_type_coding_0_code class_1_type_coding_0_display  \
# 40                       plan                          Plan
# 41                       plan                          Plan
# 42                       plan                          Plan
# 43                       plan                          Plan
# 44                       plan                          Plan
# 45                       plan                          Plan
# 46                       plan                          Plan
# 47                       plan                          Plan
# 48                       plan                          Plan
# 49                       plan                          Plan
#
#                          class_1_type_coding_0_system class_1_value  \
# 40  http://terminology.hl7.org/CodeSystem/coverage...        Part A
# 41  http://terminology.hl7.org/CodeSystem/coverage...        Part B
# 42  http://terminology.hl7.org/CodeSystem/coverage...        Part C
# 43  http://terminology.hl7.org/CodeSystem/coverage...        Part D
# 44  http://terminology.hl7.org/CodeSystem/coverage...        Part A
# 45  http://terminology.hl7.org/CodeSystem/coverage...        Part B
# 46  http://terminology.hl7.org/CodeSystem/coverage...        Part C
# 47  http://terminology.hl7.org/CodeSystem/coverage...        Part D
# 48  http://terminology.hl7.org/CodeSystem/coverage...        Part A
# 49  http://terminology.hl7.org/CodeSystem/coverage...        Part B
#
#                                       extension_0_url  ...  \
# 40  https://bluebutton.cms.gov/resources/variables...  ...
# 41  https://bluebutton.cms.gov/resources/variables...  ...
# 42  https://bluebutton.cms.gov/resources/variables...  ...
# 43  https://bluebutton.cms.gov/resources/variables...  ...
# 44  https://bluebutton.cms.gov/resources/variables...  ...
# 45  https://bluebutton.cms.gov/resources/variables...  ...
# 46  https://bluebutton.cms.gov/resources/variables...  ...
# 47  https://bluebutton.cms.gov/resources/variables...  ...
# 48  https://bluebutton.cms.gov/resources/variables...  ...
# 49  https://bluebutton.cms.gov/resources/variables...  ...
#
#    extension_107_valueCoding_display extension_108_valueCoding_display  \
# 40                               NaN                               NaN
# 41                               NaN                               NaN
# 42                               NaN                               NaN
# 43                               NaN                               NaN
# 44                               NaN                               NaN
# 45                               NaN                               NaN
# 46                               NaN                               NaN
# 47                               NaN                               NaN
# 48                               NaN                               NaN
# 49                               NaN                               NaN
#
#    extension_109_valueCoding_display extension_110_valueCoding_display  \
# 40                               NaN                               NaN
# 41                               NaN                               NaN
# 42                               NaN                               NaN
# 43                               NaN                               NaN
# 44                               NaN                               NaN
# 45                               NaN                               NaN
# 46                               NaN                               NaN
# 47                               NaN                               NaN
# 48                               NaN                               NaN
# 49                               NaN                               NaN
#
#    extension_111_valueCoding_display extension_112_valueCoding_display  \
# 40                               NaN                               NaN
# 41                               NaN                               NaN
# 42                               NaN                               NaN
# 43                               NaN                               NaN
# 44                               NaN                               NaN
# 45                               NaN                               NaN
# 46                               NaN                               NaN
# 47                               NaN                               NaN
# 48                               NaN                               NaN
# 49                               NaN                               NaN
#
#    extension_113_valueCoding_display extension_114_valueCoding_display  \
# 40                               NaN                               NaN
# 41                               NaN                               NaN
# 42                               NaN                               NaN
# 43                               NaN                               NaN
# 44                               NaN                               NaN
# 45                               NaN                               NaN
# 46                               NaN                               NaN
# 47                               NaN                               NaN
# 48                               NaN                               NaN
# 49                               NaN                               NaN
#
#    extension_115_valueCoding_display extension_116_valueCoding_display
# 40                               NaN                               NaN
# 41                               NaN                               NaN
# 42                               NaN                               NaN
# 43                               NaN                               NaN
# 44                               NaN                               NaN
# 45                               NaN                               NaN
# 46                               NaN                               NaN
# 47                               NaN                               NaN
# 48                               NaN                               NaN
# 49                               NaN                               NaN
#
# [10 rows x 638 columns]

# %%
patient_df.head(50).tail(10)
# Out:
#    address_0_state   birthDate  deceasedBoolean  \
# 40              22  1948-12-17            False
# 41              22  1952-11-17            False
# 42              22  1947-08-24            False
# 43              22  1950-02-14            False
# 44              22  1945-06-17            False
# 45              22  1948-06-23            False
# 46              22  1943-04-17            False
# 47              22  1942-09-08            False
# 48              22  1947-05-27            False
# 49              22  1943-10-06            False
#
#                                       extension_0_url extension_0_valueCode  \
# 40  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 41  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 42  http://hl7.org/fhir/us/core/StructureDefinitio...             248152002
# 43  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 44  http://hl7.org/fhir/us/core/StructureDefinitio...             248152002
# 45  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 46  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 47  http://hl7.org/fhir/us/core/StructureDefinitio...             248152002
# 48  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
# 49  http://hl7.org/fhir/us/core/StructureDefinitio...             248153007
#
#                                       extension_1_url  \
# 40  https://bluebutton.cms.gov/resources/variables...
# 41  https://bluebutton.cms.gov/resources/variables...
# 42  https://bluebutton.cms.gov/resources/variables...
# 43  https://bluebutton.cms.gov/resources/variables...
# 44  https://bluebutton.cms.gov/resources/variables...
# 45  https://bluebutton.cms.gov/resources/variables...
# 46  https://bluebutton.cms.gov/resources/variables...
# 47  https://bluebutton.cms.gov/resources/variables...
# 48  https://bluebutton.cms.gov/resources/variables...
# 49  https://bluebutton.cms.gov/resources/variables...
#
#    extension_1_valueCoding_code extension_1_valueCoding_display  \
# 40                            1                           White
# 41                            1                           White
# 42                            1                           White
# 43                            1                           White
# 44                            1                           White
# 45                            1                           White
# 46                            1                           White
# 47                            1                           White
# 48                            1                           White
# 49                            1                           White
#
#                        extension_1_valueCoding_system  \
# 40  https://bluebutton.cms.gov/resources/variables...
# 41  https://bluebutton.cms.gov/resources/variables...
# 42  https://bluebutton.cms.gov/resources/variables...
# 43  https://bluebutton.cms.gov/resources/variables...
# 44  https://bluebutton.cms.gov/resources/variables...
# 45  https://bluebutton.cms.gov/resources/variables...
# 46  https://bluebutton.cms.gov/resources/variables...
# 47  https://bluebutton.cms.gov/resources/variables...
# 48  https://bluebutton.cms.gov/resources/variables...
# 49  https://bluebutton.cms.gov/resources/variables...
#
#    extension_2_extension_0_url  ... address_0_postalCode identifier_2_system  \
# 40                 ombCategory  ...                01906                 NaN
# 41                 ombCategory  ...                  NaN                 NaN
# 42                 ombCategory  ...                  NaN                 NaN
# 43                 ombCategory  ...                02169                 NaN
# 44                 ombCategory  ...                01945                 NaN
# 45                 ombCategory  ...                  NaN                 NaN
# 46                 ombCategory  ...                01902                 NaN
# 47                 ombCategory  ...                  NaN                 NaN
# 48                 ombCategory  ...                02163                 NaN
# 49                 ombCategory  ...                02542                 NaN
#
#    identifier_2_type_coding_0_code identifier_2_type_coding_0_display  \
# 40                             NaN                                NaN
# 41                             NaN                                NaN
# 42                             NaN                                NaN
# 43                             NaN                                NaN
# 44                             NaN                                NaN
# 45                             NaN                                NaN
# 46                             NaN                                NaN
# 47                             NaN                                NaN
# 48                             NaN                                NaN
# 49                             NaN                                NaN
#
#    identifier_2_type_coding_0_extension_0_url  \
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN
#
#    identifier_2_type_coding_0_extension_0_valueCoding_code  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    identifier_2_type_coding_0_extension_0_valueCoding_display  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    identifier_2_type_coding_0_extension_0_valueCoding_system  \
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    identifier_2_type_coding_0_system  identifier_2_value
# 40                               NaN                 NaN
# 41                               NaN                 NaN
# 42                               NaN                 NaN
# 43                               NaN                 NaN
# 44                               NaN                 NaN
# 45                               NaN                 NaN
# 46                               NaN                 NaN
# 47                               NaN                 NaN
# 48                               NaN                 NaN
# 49                               NaN                 NaN
#
# [10 rows x 50 columns]

# %%
#claim_df.head(50).tail(10)

# %%
claim_response_df.head(50).tail(10)
# Out:
#    contained_0_birthDate                        contained_0_extension_0_url  \
# 40            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 41            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 42            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 43            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 44            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 45            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 46            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 47            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 48            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
# 49            1948-09-05  http://hl7.org/fhir/us/core/StructureDefinitio...
#
#    contained_0_extension_0_valueCode contained_0_gender contained_0_id  \
# 40                         248153007               male        patient
# 41                         248153007               male        patient
# 42                         248153007               male        patient
# 43                         248153007               male        patient
# 44                         248153007               male        patient
# 45                         248153007               male        patient
# 46                         248153007               male        patient
# 47                         248153007               male        patient
# 48                         248153007               male        patient
# 49                         248153007               male        patient
#
#    contained_0_identifier_0_system  \
# 40  http://hl7.org/fhir/sid/us-mbi
# 41  http://hl7.org/fhir/sid/us-mbi
# 42  http://hl7.org/fhir/sid/us-mbi
# 43  http://hl7.org/fhir/sid/us-mbi
# 44  http://hl7.org/fhir/sid/us-mbi
# 45  http://hl7.org/fhir/sid/us-mbi
# 46  http://hl7.org/fhir/sid/us-mbi
# 47  http://hl7.org/fhir/sid/us-mbi
# 48  http://hl7.org/fhir/sid/us-mbi
# 49  http://hl7.org/fhir/sid/us-mbi
#
#    contained_0_identifier_0_type_coding_0_code  \
# 40                                          MC
# 41                                          MC
# 42                                          MC
# 43                                          MC
# 44                                          MC
# 45                                          MC
# 46                                          MC
# 47                                          MC
# 48                                          MC
# 49                                          MC
#
#    contained_0_identifier_0_type_coding_0_display  \
# 40                      Patient's Medicare Number
# 41                      Patient's Medicare Number
# 42                      Patient's Medicare Number
# 43                      Patient's Medicare Number
# 44                      Patient's Medicare Number
# 45                      Patient's Medicare Number
# 46                      Patient's Medicare Number
# 47                      Patient's Medicare Number
# 48                      Patient's Medicare Number
# 49                      Patient's Medicare Number
#
#     contained_0_identifier_0_type_coding_0_system  \
# 40  http://terminology.hl7.org/CodeSystem/v2-0203
# 41  http://terminology.hl7.org/CodeSystem/v2-0203
# 42  http://terminology.hl7.org/CodeSystem/v2-0203
# 43  http://terminology.hl7.org/CodeSystem/v2-0203
# 44  http://terminology.hl7.org/CodeSystem/v2-0203
# 45  http://terminology.hl7.org/CodeSystem/v2-0203
# 46  http://terminology.hl7.org/CodeSystem/v2-0203
# 47  http://terminology.hl7.org/CodeSystem/v2-0203
# 48  http://terminology.hl7.org/CodeSystem/v2-0203
# 49  http://terminology.hl7.org/CodeSystem/v2-0203
#
#    contained_0_identifier_0_value  ...               meta_lastUpdated outcome  \
# 40                    1S00E00KF44  ...  2023-05-11T21:21:15.113+00:00  queued
# 41                    1S00E00KF44  ...  2023-05-11T21:21:15.130+00:00  queued
# 42                    1S00E00KF44  ...  2023-05-11T21:21:15.113+00:00  queued
# 43                    1S00E00KF44  ...  2023-05-11T21:21:15.384+00:00  queued
# 44                    1S00E00KF44  ...  2023-05-11T21:21:15.130+00:00  queued
# 45                    1S00E00KF44  ...  2023-05-11T21:21:15.384+00:00  queued
# 46                    1S00E00KF44  ...  2023-05-11T21:21:15.113+00:00  queued
# 47                    1S00E00KF44  ...  2023-05-11T21:21:15.130+00:00  queued
# 48                    1S00E00KF44  ...  2023-05-11T21:21:15.113+00:00  queued
# 49                    1S00E00KF44  ...  2023-05-11T21:21:15.130+00:00  queued
#
#    patient_reference             request_reference   resourceType  status  \
# 40          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjc0  ClaimResponse  active
# 41          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjc3  ClaimResponse  active
# 42          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjc5  ClaimResponse  active
# 43          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjcx  ClaimResponse  active
# 44          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjcz  ClaimResponse  active
# 45          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjg0  ClaimResponse  active
# 46          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjg2  ClaimResponse  active
# 47          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjg5  ClaimResponse  active
# 48          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjgy  ClaimResponse  active
# 49          #patient  Claim/f-LTEwMDAwMDAzNjY4Mjk1  ClaimResponse  active
#
#    type_coding_0_code type_coding_0_display  \
# 40      institutional         Institutional
# 41      institutional         Institutional
# 42      institutional         Institutional
# 43      institutional         Institutional
# 44      institutional         Institutional
# 45      institutional         Institutional
# 46      institutional         Institutional
# 47      institutional         Institutional
# 48      institutional         Institutional
# 49      institutional         Institutional
#
#                                 type_coding_0_system    use
# 40  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 41  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 42  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 43  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 44  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 45  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 46  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 47  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 48  http://terminology.hl7.org/CodeSystem/claim-type  claim
# 49  http://terminology.hl7.org/CodeSystem/claim-type  claim
#
# [10 rows x 39 columns]

# %%
# Checking for missing values
print("\nMissing values in explanation_of_benefit_df:")
print(explanation_of_benefit_df.isnull().sum())

print("\nMissing values in  coverage_df:")
print(coverage_df.isnull().sum())

print("\nMissing values in patient_df:")
print(patient_df.isnull().sum())

# print("\nMissing values in claim_df:")
# print(claim_df.isnull().sum())

print("\nMissing values in claim_response_df:")
print(claim_response_df.isnull().sum())
# Out:
# Missing values in explanation_of_benefit_df:
# benefitBalance_0_category_coding_0_code                   1645
# benefitBalance_0_category_coding_0_display                1645
# benefitBalance_0_category_coding_0_system                 1645
# benefitBalance_0_financial_0_type_coding_0_code           1645
# benefitBalance_0_financial_0_type_coding_0_display        1645
#                                                           ...
# procedure_20_procedureCodeableConcept_coding_0_system     5475
# procedure_20_procedureCodeableConcept_coding_1_code       5475
# procedure_20_procedureCodeableConcept_coding_1_display    5475
# procedure_20_procedureCodeableConcept_coding_1_system     5475
# procedure_20_sequence                                     5475
# Length: 900, dtype: int64
#
# Missing values in  coverage_df:
# beneficiary_reference                  0
# class_0_type_coding_0_code             0
# class_0_type_coding_0_display          0
# class_0_type_coding_0_system           0
# class_0_value                          0
#                                     ...
# extension_112_valueCoding_display    372
# extension_113_valueCoding_display    372
# extension_114_valueCoding_display    372
# extension_115_valueCoding_display    372
# extension_116_valueCoding_display    372
# Length: 638, dtype: int64
#
# Missing values in patient_df:
# address_0_state                                                0
# birthDate                                                      0
# deceasedBoolean                                                0
# extension_0_url                                                0
# extension_0_valueCode                                          0
# extension_1_url                                                0
# extension_1_valueCoding_code                                   0
# extension_1_valueCoding_display                                0
# extension_1_valueCoding_system                                 0
# extension_2_extension_0_url                                    0
# extension_2_extension_0_valueCoding_code                       0
# extension_2_extension_0_valueCoding_display                    0
# extension_2_extension_0_valueCoding_system                     0
# extension_2_extension_1_url                                    0
# extension_2_extension_1_valueString                            0
# extension_2_url                                                0
# extension_3_url                                                0
# extension_3_valueDate                                          0
# gender                                                         0
# id                                                             0
# identifier_0_system                                            0
# identifier_0_type_coding_0_code                                0
# identifier_0_type_coding_0_display                             0
# identifier_0_type_coding_0_system                              0
# identifier_0_value                                             0
# identifier_1_system                                            0
# identifier_1_type_coding_0_code                                0
# identifier_1_type_coding_0_display                             0
# identifier_1_type_coding_0_extension_0_url                     0
# identifier_1_type_coding_0_extension_0_valueCoding_code        0
# identifier_1_type_coding_0_extension_0_valueCoding_display     0
# identifier_1_type_coding_0_extension_0_valueCoding_system      0
# identifier_1_type_coding_0_system                              0
# identifier_1_value                                             0
# meta_lastUpdated                                               0
# meta_profile                                                   0
# name_0_family                                                  0
# name_0_given                                                   0
# name_0_use                                                     0
# resourceType                                                   0
# address_0_postalCode                                          40
# identifier_2_system                                           99
# identifier_2_type_coding_0_code                               99
# identifier_2_type_coding_0_display                            99
# identifier_2_type_coding_0_extension_0_url                    99
# identifier_2_type_coding_0_extension_0_valueCoding_code       99
# identifier_2_type_coding_0_extension_0_valueCoding_display    99
# identifier_2_type_coding_0_extension_0_valueCoding_system     99
# identifier_2_type_coding_0_system                             99
# identifier_2_value                                            99
# dtype: int64
#
# Missing values in claim_response_df:
# contained_0_birthDate                             1528
# contained_0_extension_0_url                          0
# contained_0_extension_0_valueCode                    0
# contained_0_gender                                   0
# contained_0_id                                       0
# contained_0_identifier_0_system                      0
# contained_0_identifier_0_type_coding_0_code          0
# contained_0_identifier_0_type_coding_0_display       0
# contained_0_identifier_0_type_coding_0_system        0
# contained_0_identifier_0_value                       0
# contained_0_name_0_family                            0
# contained_0_name_0_given                             0
# contained_0_name_0_text                              0
# contained_0_resourceType                             0
# created                                              0
# extension_0_url                                      0
# extension_0_valueCoding_code                         0
# extension_0_valueCoding_system                       0
# extension_1_url                                      0
# extension_1_valueDate                                0
# extension_2_url                                      0
# extension_2_valueDate                                0
# id                                                   0
# identifier_0_system                                  0
# identifier_0_type_coding_0_code                      0
# identifier_0_type_coding_0_display                   0
# identifier_0_type_coding_0_system                    0
# identifier_0_value                                   0
# insurer_identifier_value                             0
# meta_lastUpdated                                     0
# outcome                                              0
# patient_reference                                    0
# request_reference                                    0
# resourceType                                         0
# status                                               0
# type_coding_0_code                                   0
# type_coding_0_display                                0
# type_coding_0_system                                 0
# use                                                  0
# dtype: int64

# %%
# Checking basic statistics
print("\nBasic Statistics for Explanation of Benefit:")
print(explanation_of_benefit_df.describe())

print("\nBasic Statistics for Coverage:")
print(coverage_df.describe())

# print("\nBasic Statistics for Patient:")
# print(patient_df.describe())

print("\nBasic Statistics for Claim Response:")
print(claim_response_df.describe())
# Out:
# Basic Statistics for Explanation of Benefit:
#        benefitBalance_0_financial_0_usedMoney_value  \
# count                                   3807.000000
# mean                                      44.050239
# std                                      146.609344
# min                                        0.000000
# 25%                                        4.000000
# 50%                                        4.000000
# 75%                                       10.000000
# max                                      900.000000
#
#        benefitBalance_0_financial_1_usedMoney_value  \
# count                                   3759.000000
# mean                                    1000.843642
# std                                     3939.128007
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                      992.990000
# max                                    55664.460000
#
#        benefitBalance_0_financial_2_usedMoney_value  \
# count                                   3754.000000
# mean                                       5.729888
# std                                        7.930724
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                       10.000000
# max                                       20.000000
#
#        benefitBalance_0_financial_3_usedUnsignedInt  \
# count                                         143.0
# mean                                            0.0
# std                                             0.0
# min                                             0.0
# 25%                                             0.0
# 50%                                             0.0
# 75%                                             0.0
# max                                             0.0
#
#        benefitBalance_0_financial_4_usedUnsignedInt  \
# count                                         143.0
# mean                                            0.0
# std                                             0.0
# min                                             0.0
# 25%                                             0.0
# 50%                                             0.0
# 75%                                             0.0
# max                                             0.0
#
#        benefitBalance_0_financial_5_usedMoney_value  \
# count                                   2324.000000
# mean                                     202.108567
# std                                     3367.088698
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                   112529.130000
#
#        benefitBalance_0_financial_6_usedMoney_value  \
# count                                   2324.000000
# mean                                     443.471437
# std                                     2993.703025
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                    66204.340000
#
#        benefitBalance_0_financial_7_usedMoney_value  \
# count                                    162.000000
# mean                                    3951.953395
# std                                     9552.433105
# min                                        0.000000
# 25%                                       40.000000
# 50%                                      117.020000
# 75%                                      334.832500
# max                                    51515.140000
#
#        benefitBalance_0_financial_8_usedMoney_value  \
# count                                     162.00000
# mean                                     6662.07284
# std                                     21635.36306
# min                                         0.00000
# 25%                                        57.83000
# 50%                                       120.00000
# 75%                                       637.65000
# max                                    199704.26000
#
#        benefitBalance_0_financial_9_usedMoney_value  ...  \
# count                                         143.0  ...
# mean                                            0.0  ...
# std                                             0.0  ...
# min                                             0.0  ...
# 25%                                             0.0  ...
# 50%                                             0.0  ...
# 75%                                             0.0  ...
# max                                             0.0  ...
#
#        procedure_16_sequence  procedure_17_sequence  procedure_18_sequence  \
# count                    7.0                    5.0                    3.0
# mean                    17.0                   18.0                   19.0
# std                      0.0                    0.0                    0.0
# min                     17.0                   18.0                   19.0
# 25%                     17.0                   18.0                   19.0
# 50%                     17.0                   18.0                   19.0
# 75%                     17.0                   18.0                   19.0
# max                     17.0                   18.0                   19.0
#
#        supportingInfo_5_valueQuantity_value  diagnosis_14_sequence  \
# count                             53.000000                   40.0
# mean                               6.188679                   15.0
# std                                3.632421                    0.0
# min                                1.000000                   15.0
# 25%                                3.000000                   15.0
# 50%                                6.000000                   15.0
# 75%                                9.000000                   15.0
# max                               14.000000                   15.0
#
#        diagnosis_15_sequence  procedure_19_sequence  diagnosis_16_sequence  \
# count                   35.0                    2.0                    2.0
# mean                    16.0                   20.0                   17.0
# std                      0.0                    0.0                    0.0
# min                     16.0                   20.0                   17.0
# 25%                     16.0                   20.0                   17.0
# 50%                     16.0                   20.0                   17.0
# 75%                     16.0                   20.0                   17.0
# max                     16.0                   20.0                   17.0
#
#        diagnosis_17_sequence  procedure_20_sequence
# count                    1.0                    1.0
# mean                    18.0                   21.0
# std                      NaN                    NaN
# min                     18.0                   21.0
# 25%                     18.0                   21.0
# 50%                     18.0                   21.0
# 75%                     18.0                   21.0
# max                     18.0                   21.0
#
# [8 rows x 117 columns]
#
# Basic Statistics for Coverage:
#           beneficiary_reference class_0_type_coding_0_code  \
# count                       400                        400
# unique                      100                          1
# top     Patient/-10000000000010                      group
# freq                          4                        400
#
#        class_0_type_coding_0_display  \
# count                            400
# unique                             1
# top                            Group
# freq                             400
#
#                              class_0_type_coding_0_system class_0_value  \
# count                                                 400           400
# unique                                                  1             1
# top     http://terminology.hl7.org/CodeSystem/coverage...      Medicare
# freq                                                  400           400
#
#        class_1_type_coding_0_code class_1_type_coding_0_display  \
# count                         400                           400
# unique                          1                             1
# top                          plan                          Plan
# freq                          400                           400
#
#                              class_1_type_coding_0_system class_1_value  \
# count                                                 400           400
# unique                                                  1             4
# top     http://terminology.hl7.org/CodeSystem/coverage...        Part A
# freq                                                  400           100
#
#                                           extension_0_url  ...  \
# count                                                 400  ...
# unique                                                  2  ...
# top     https://bluebutton.cms.gov/resources/variables...  ...
# freq                                                  300  ...
#
#           extension_107_valueCoding_display  \
# count                                    24
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     24
#
#           extension_108_valueCoding_display  \
# count                                    24
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     24
#
#           extension_109_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_110_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_111_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_112_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_113_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_114_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_115_valueCoding_display  \
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
#           extension_116_valueCoding_display
# count                                    28
# unique                                    1
# top     Not Medicare enrolled for the month
# freq                                     28
#
# [4 rows x 638 columns]
#
# Basic Statistics for Claim Response:
#        contained_0_birthDate  \
# count                   7033
# unique                   117
# top               1942-07-09
# freq                    2410
#
#                               contained_0_extension_0_url  \
# count                                                8561
# unique                                                  1
# top     http://hl7.org/fhir/us/core/StructureDefinitio...
# freq                                                 8561
#
#        contained_0_extension_0_valueCode contained_0_gender contained_0_id  \
# count                               8561               8561           8561
# unique                                 2                  2              1
# top                            248153007               male        patient
# freq                                5304               5304           8561
#
#        contained_0_identifier_0_system  \
# count                             8561
# unique                               1
# top     http://hl7.org/fhir/sid/us-mbi
# freq                              8561
#
#        contained_0_identifier_0_type_coding_0_code  \
# count                                         8561
# unique                                           1
# top                                             MC
# freq                                          8561
#
#        contained_0_identifier_0_type_coding_0_display  \
# count                                            8561
# unique                                              1
# top                         Patient's Medicare Number
# freq                                             8561
#
#         contained_0_identifier_0_type_coding_0_system  \
# count                                            8561
# unique                                              1
# top     http://terminology.hl7.org/CodeSystem/v2-0203
# freq                                             8561
#
#        contained_0_identifier_0_value  ...               meta_lastUpdated  \
# count                            8561  ...                           8561
# unique                            110  ...                           2843
# top                       1S00E00MD69  ...  2023-05-11T21:22:12.233+00:00
# freq                             2436  ...                             24
#
#        outcome patient_reference   request_reference   resourceType  status  \
# count     8561              8561                8561           8561    8561
# unique       1                 1                8561              1       1
# top     queued          #patient  Claim/m--100446109  ClaimResponse  active
# freq      8561              8561                   1           8561    8561
#
#        type_coding_0_code type_coding_0_display  \
# count                8561                  8561
# unique                  2                     2
# top         institutional         Institutional
# freq                 7033                  7033
#
#                                     type_coding_0_system    use
# count                                               8561   8561
# unique                                                 1      1
# top     http://terminology.hl7.org/CodeSystem/claim-type  claim
# freq                                                8561   8561
#
# [4 rows x 39 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cff59b50-5bfa-41ed-b840-afb0c6e184df' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
